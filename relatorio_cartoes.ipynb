# %% [markdown]
# ## Estatísticas de Meios de Pagamentos
#
# Este conjunto contém diversas estatísticas relacionadas aos seguintes MEIOS DE PAGAMENTO:
#
# Instrumentos de periodicidade mensal, com atualização 17 dias após o final do mês de referência:
#
# Pix (fonte: SPI e documento 1201);
# TED (fonte: CIP-SITRAF e STR);
# Boletos (fonte: CIP-SILOC);
# DOC e TEC (fonte: CIP-SILOC);
# Cheque (fonte: Compe).
# Instrumentos de periodicidade trimestral, com atualização 2 meses após o final do trimestre de referência:
#
# Cartões de crédito, débito e pré-pagos (fonte: documentos 6308 e 6334);
# Pagamentos de convênio, saques, transferências intrabancárias e débito direto (fonte: documento 6209);
# Volumetria das transações intrabancárias (fonte: documento 6209);
# Estabelecimentos credenciados (fonte: documento 6334);
# Volumetria por canal de acesso e produto (fonte: documento 6209);
# Quantidade de ATMs (fonte: documento 6209);
# Tarifas de intercâmbio (TIC) e taxas de desconto (MDR) - (fonte: documento 6334);
# Terminais POS/PDV;
# Programas de recompensa e fidelidade.
#
# Dicionário de dados
#
# | Nome                         | Tipo    | Título                                    | Descrição                                                                                                                                                                                                                                       |
# | ---------------------------- | ------- | ----------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | datatrimestre                | texto   | Trimestre                                 |                                                                                                                                                                                                                                                 |
# | valorPix                     | decimal | Valor Pix                                 | Volume financeiro (R\$ milhões) de transações Pix liquidadas trimestralmente no SPI e fora do SPI, considerando ordens de pagamento e devoluções no período. Dados referentes às transações liquidadas fora do SPI estão sujeitas a alterações. |
# | valorTED                     | decimal | Valor TED                                 | Montante financeiro (R\$ milhões) trimestral transferido por meio de TED. Transferência Eletrônica Direta (TED) em tempo real entre diferentes instituições, usada para transferir valores entre correntistas e entre instituições.             |
# | valorTEC                     | decimal | Valor TEC                                 | Montante financeiro (R\$ milhões) trimestral transferido por meio de TEC. Transferência Especial de Crédito (TEC) utilizada por empresas para pagamento de benefícios aos empregados.                                                           |
# | valorCheque                  | decimal | Valor Cheque                              | Montante financeiro (R\$ milhões) de cheques interbancários e intrabancários compensados trimestralmente.                                                                                                                                       |
# | valorBoleto                  | decimal | Valor Boleto                              | Montante financeiro (R\$ milhões) de boletos interbancários e intrabancários compensados trimestralmente.                                                                                                                                       |
# | valorDOC                     | decimal | Valor DOC                                 | Montante financeiro (R\$ milhões) trimestral transferido por meio de DOC.                                                                                                                                                                       |
# | valorCartaoCredito           | decimal | Valor Cartão de Crédito                   | Valor (R\$ milhões) de transações realizadas com cartão de crédito.                                                                                                                                                                             |
# | valorCartaoDebito            | decimal | Valor Cartão de Débito                    | Valor (R\$ milhões) de transações realizadas com cartão de débito trimestralmente.                                                                                                                                                              |
# | valorCartaoPrePago           | decimal | Valor Cartão Pré-pago                     | Valor (R\$ milhões) de transações realizadas com cartão pré-pago trimestralmente.                                                                                                                                                               |
# | valorTransIntrabancaria      | decimal | Valor Transferência Intrabancária         | Montante financeiro (R\$ milhões) de transferências realizadas trimestralmente entre contas de clientes da Instituição, inclusive aplicações e resgates em fundos de investimento.                                                              |
# | valorConvenios               | decimal | Valor Convênio                            | Montante financeiro (R\$ milhões) de arrecadações trimestrais governamentais (tributos e encargos sociais) e não-governamentais, em virtude de convênios firmados entre a instituição e entidades públicas ou privadas.                         |
# | valorDebitoDireto            | decimal | Valor Débito Direto                       | Montante financeiro (R\$ milhões) trimestral de débitos previamente autorizados pelo cliente, referente a contas recorrentes e tarifas de serviços.                                                                                             |
# | valorSaques                  | decimal | Valor Saque                               | Montante sacado (R\$ milhões) nos caixas eletrônicos trimestralmente.                                                                                                                                                                           |
# | quantidadePix                | decimal | Quantidade Pix                            | Quantidade (em milhares) de transações Pix liquidadas trimestralmente no SPI e fora do SPI, considerando ordens de pagamento e devoluções.                                                                                                      |
# | quantidadeTED                | decimal | Quantidade TED                            | Quantidade (em milhares) de TED realizadas trimestralmente.                                                                                                                                                                                     |
# | quantidadeTEC                | decimal | Quantidade TEC                            | Quantidade (em milhares) de TEC realizadas trimestralmente.                                                                                                                                                                                     |
# | quantidadeCheque             | decimal | Quantidade Cheque                         | Quantidade (em milhares) de cheques interbancários e intrabancários compensados trimestralmente.                                                                                                                                                |
# | quantidadeBoleto             | decimal | Quantidade Boleto                         | Quantidade (em milhares) de boletos interbancários e intrabancários compensados trimestralmente.                                                                                                                                                |
# | quantidadeDOC                | decimal | Quantidade DOC                            | Quantidade (em milhares) de DOC realizados trimestralmente.                                                                                                                                                                                     |
# | quantidadeCartaoCredito      | decimal | Quantidade Cartão de Crédito              | Quantidade (em milhares) de transações realizadas com cartão de crédito trimestralmente.                                                                                                                                                        |
# | quantidadeCartaoDebito       | decimal | Quantidade Cartão de Débito               | Quantidade (em milhares) de transações realizadas com cartão de débito trimestralmente.                                                                                                                                                         |
# | quantidadeCartaoPrePago      | decimal | Quantidade Cartão Pré-pago                | Quantidade (em milhares) de transações realizadas com cartão pré-pago trimestralmente.                                                                                                                                                          |
# | quantidadeTransIntrabancaria | decimal | Quantidade de Transferência Intrabancária | Quantidade (em milhares) de transferências realizadas trimestralmente entre contas de clientes da Instituição, inclusive aplicações e resgates em fundos de investimento.                                                                       |
# | quantidadeConvenios          | decimal | Quantidade Convênio                       | Quantidade (em milhares) de arrecadações trimestrais governamentais e não-governamentais referentes a convênios firmados entre a instituição e entidades públicas ou privadas.                                                                  |
# | quantidadeDebitoDireto       | decimal | Quantidade Débito Direto                  | Quantidade (em milhares) de transações trimestrais de débitos previamente autorizados pelo cliente, referentes a contas recorrentes e tarifas de serviços.                                                                                      |
# | quantidadeSaques             | decimal | Quantidade de Saque                       | Quantidade (em milhares) de saques realizados nos caixas eletrônicos trimestralmente.                                                                                                                                                           |

# %% [markdown]
# ## Análise exploratória dos Cartões de Crédito

# %%
import pandas as pd
import sqlite3

con = sqlite3.connect("src/datasets/etlbcb.db")
query = "select * from meios_pagamentos_tri"
df = pd.read_sql(query, con)
con.close()

# %% [markdown]
# Primeiro vamos explorar a estrutura do conjunto de dados

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 27 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   datatrimestre                 25 non-null     object
#  1   valorPix                      25 non-null     float64
#  2   valorTED                      25 non-null     float64
#  3   valorTEC                      25 non-null     float64
#  4   valorCheque                   25 non-null     float64
#  5   valorBoleto                   25 non-null     float64
#  6   valorDOC                      25 non-null     float64
#  7   valorCartaoCredito            25 non-null     float64
#  8   valorCartaoDebito             25 non-null     float64
#  9   valorCartaoPrePago            25 non-null     float64
#  10  valorTransIntrabancaria       25 non-null     float64
#  11  valorConvenios                25 non-null     float64
# ...

# %% [markdown]
# Aparentemente não temos dados faltantes, mas vamos comprovar:

# %%
df.isnull().sum()
# Out:
# datatrimestre                   0
# valorPix                        0
# valorTED                        0
# valorTEC                        0
# valorCheque                     0
# valorBoleto                     0
# valorDOC                        0
# valorCartaoCredito              0
# valorCartaoDebito               0
# valorCartaoPrePago              0
# valorTransIntrabancaria         0
# valorConvenios                  0
# valorDebitoDireto               0
# valorSaques                     0
# quantidadePix                   0
# quantidadeTED                   0
# quantidadeTEC                   0
# quantidadeCheque                0
# quantidadeBoleto                0
# quantidadeDOC                   0
# quantidadeCartaoCredito         0
# quantidadeCartaoDebito          0
# quantidadeCartaoPrePago         0
# quantidadeTransIntrabancaria    0
# quantidadeConvenios             0
# quantidadeDebitoDireto          0
# quantidadeSaques                0
# dtype: int64

# %% [markdown]
# Note que data trimestre está como object(string), mas seria mais interessante estar como Date. Vamos comprovar isso.

# %%
type(df['datatrimestre'][0])
# Out:
# str

# %% [markdown]
# Convertendo para 'date'.

# %%
df['datatrimestre'] = pd.to_datetime(df['datatrimestre'])
df['datatrimestre'] = df['datatrimestre'].dt.date

# %% [markdown]
# Verificando a conversão para conter apenas a data, sem horário.

# %%
type(df['datatrimestre'][0])
# Out:
# datetime.date

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 27 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   datatrimestre                 25 non-null     object
#  1   valorPix                      25 non-null     float64
#  2   valorTED                      25 non-null     float64
#  3   valorTEC                      25 non-null     float64
#  4   valorCheque                   25 non-null     float64
#  5   valorBoleto                   25 non-null     float64
#  6   valorDOC                      25 non-null     float64
#  7   valorCartaoCredito            25 non-null     float64
#  8   valorCartaoDebito             25 non-null     float64
#  9   valorCartaoPrePago            25 non-null     float64
#  10  valorTransIntrabancaria       25 non-null     float64
#  11  valorConvenios                25 non-null     float64
# ...

# %% [markdown]
# Ajustando as colunas que estão em milhões.

# %%
monetary_cols = [
    'valorPix', 'valorTED', 'valorTEC', 'valorCheque', 'valorBoleto',
    'valorDOC', 'valorCartaoCredito', 'valorCartaoDebito', 'valorCartaoPrePago',
    'valorTransIntrabancaria', 'valorConvenios', 'valorDebitoDireto', 'valorSaques'
]

for col in monetary_cols:
    df[col] = df[col] * 1_000_000
    df[col] = df[col].round(2)

# %%
df
# Out:
#    datatrimestre      valorPix      valorTED      valorTEC   valorCheque  \
# 0     2025-03-31  7.472954e+12  1.076769e+13  0.000000e+00  1.706379e+11
# 1     2024-12-31  7.714130e+12  1.164727e+13  0.000000e+00  1.874864e+11
# 2     2024-09-30  6.976429e+12  1.118022e+13  0.000000e+00  1.943306e+11
# 3     2024-06-30  6.284296e+12  1.066256e+13  0.000000e+00  2.215538e+11
# 4     2024-03-31  5.429305e+12  9.651626e+12  9.252600e+08  1.904572e+11
# 5     2023-12-31  5.300155e+12  1.009092e+13  5.787890e+09  2.214248e+11
# 6     2023-09-30  4.469530e+12  9.960252e+12  4.156380e+09  2.181219e+11
# 7     2023-06-30  3.900377e+12  1.065746e+13  4.770740e+09  2.284088e+11
# 8     2023-03-31  3.447198e+12  9.919603e+12  4.535170e+09  2.406862e+11
# 9     2022-12-31  3.342914e+12  1.038212e+13  5.609530e+09  2.422596e+11
# 10    2022-09-30  2.936414e+12  1.043776e+13  3.735460e+09  2.670902e+11
# 11    2022-06-30  2.543384e+12  1.044957e+13  4.786140e+09  2.710081e+11
# ...

# %% [markdown]
# Ajustando as colunas que estão em milhares

# %%
thousands_cols = [
    'quantidadePix', 'quantidadeTED', 'quantidadeTEC', 'quantidadeCheque',
    'quantidadeBoleto', 'quantidadeDOC', 'quantidadeCartaoCredito',
    'quantidadeCartaoDebito', 'quantidadeCartaoPrePago',
    'quantidadeTransIntrabancaria', 'quantidadeConvenios',
    'quantidadeDebitoDireto', 'quantidadeSaques'
]

for col in thousands_cols:
    df[col] = df[col].round(0) * 1_000

# %%
df
# Out:
#    datatrimestre      valorPix      valorTED      valorTEC   valorCheque  \
# 0     2025-03-31  7.472954e+12  1.076769e+13  0.000000e+00  1.706379e+11
# 1     2024-12-31  7.714130e+12  1.164727e+13  0.000000e+00  1.874864e+11
# 2     2024-09-30  6.976429e+12  1.118022e+13  0.000000e+00  1.943306e+11
# 3     2024-06-30  6.284296e+12  1.066256e+13  0.000000e+00  2.215538e+11
# 4     2024-03-31  5.429305e+12  9.651626e+12  9.252600e+08  1.904572e+11
# 5     2023-12-31  5.300155e+12  1.009092e+13  5.787890e+09  2.214248e+11
# 6     2023-09-30  4.469530e+12  9.960252e+12  4.156380e+09  2.181219e+11
# 7     2023-06-30  3.900377e+12  1.065746e+13  4.770740e+09  2.284088e+11
# 8     2023-03-31  3.447198e+12  9.919603e+12  4.535170e+09  2.406862e+11
# 9     2022-12-31  3.342914e+12  1.038212e+13  5.609530e+09  2.422596e+11
# 10    2022-09-30  2.936414e+12  1.043776e+13  3.735460e+09  2.670902e+11
# 11    2022-06-30  2.543384e+12  1.044957e+13  4.786140e+09  2.710081e+11
# ...

# %% [markdown]
# ## Estatísticas Descritivas
#
# Nosso conjunto de dados está com muitas colunas, vamos nos concentrar em um tema específico para continuar com a análise.
#
# Vamos nos concentrar nas séries de cartões de crédito, débito e pré-pago.

# %%
date_col = ['datatrimestre']

cartao_cols = [
    'valorCartaoCredito', 'quantidadeCartaoCredito',
    'valorCartaoDebito',  'quantidadeCartaoDebito',
    'valorCartaoPrePago', 'quantidadeCartaoPrePago'
]

selected_cols = date_col+cartao_cols
df_cards = df[selected_cols].copy()

# %%
df_cards.describe()
# Out:
#        valorCartaoCredito  quantidadeCartaoCredito  valorCartaoDebito  \
# count        2.500000e+01             2.500000e+01       2.500000e+01
# mean         4.543250e+11             3.626616e+09       2.221507e+11
# std          1.606579e+11             1.099709e+09       3.637140e+10
# min          2.243895e+11             1.907929e+09       1.517647e+11
# 25%          3.028882e+11             2.584404e+09       2.047529e+11
# 50%          4.679112e+11             3.741214e+09       2.351116e+11
# 75%          5.819024e+11             4.583772e+09       2.436329e+11
# max          7.290272e+11             5.355789e+09       2.641206e+11
#
#        quantidadeCartaoDebito  valorCartaoPrePago  quantidadeCartaoPrePago
# count            2.500000e+01        2.500000e+01             2.500000e+01
# mean             3.501891e+09        4.349794e+10             1.709089e+09
# std              6.133983e+08        2.863550e+10             1.138438e+09
# ...

# %% [markdown]
# ## Estudo das médias

# %% [markdown]
# Existem formas diferentes de encontrar as médias em questão. Vejamos:

# %%
soma1 = df_cards['valorCartaoCredito'].sum()
soma2 = df_cards['quantidadeCartaoCredito'].sum()

soma1/soma2
# Out:
# np.float64(125.27520025998012)

# %%
(df_cards['valorCartaoCredito']/df_cards['quantidadeCartaoCredito']).mean()
# Out:
# np.float64(123.30356692928986)

# %%
soma1 = df_cards['valorCartaoDebito'].sum()
soma2 = df_cards['quantidadeCartaoDebito'].sum()

soma1/soma2
# Out:
# np.float64(63.43736985245377)

# %%
(df_cards['valorCartaoDebito']/df_cards['quantidadeCartaoDebito']).mean()
# Out:
# np.float64(63.69625376915085)

# %%
soma1 = df_cards['valorCartaoPrePago'].sum()
soma2 = df_cards['quantidadeCartaoPrePago'].sum()

soma1/soma2
# Out:
# np.float64(25.450943153660976)

# %%
(df_cards['valorCartaoPrePago']/df_cards['quantidadeCartaoPrePago']).mean()
# Out:
# np.float64(32.07839566107721)

# %% [markdown]
#  A diferença existe porque, na segunda abordagem de cada série, está dando peso igual a cada trimestre, independentemente de quantas transações ocorreram naquele período. Já na primeira, cada transação — seja no trimestre que for — “conta” igualmente, o que faz o trimestre com mais transações influenciar mais o resultado final.
#
#  | Métrica                                  | Fórmula                                                    | Interpretação                                                  |
# | ---------------------------------------- | ---------------------------------------------------------- | -------------------------------------------------------------- |
# | Média geral (ponderada)                  | $\sum_i valorPix_i \,/\, \sum_i quantidadePix_i$           | Valor médio por transação considerando todo o volume           |
# | Média das médias trimestrais (não-pond.) | $\tfrac{1}{n}\sum_i\bigl(valorPix_i/quantidadePix_i\bigr)$ | Valor médio por transação onde cada trimestre tem “peso” igual |
#
# Use a **média geral** quando quiser o valor médio de toda a amostra, e a **média das médias trimestrais** quando quiser tratar cada período (trimestre) com igual importância.

# %% [markdown]
# ## Variância e Desvio-Padrão

# %% [markdown]
# Cartão de Crédito

# %%
x1 = df_cards['valorCartaoCredito'] / df_cards['quantidadeCartaoCredito']
print("Média:", x1.mean())
print("Variância:", x1.var(ddof=0))
print("Desvio-Padrão:", x1.std(ddof=0))
# Out:
# Média: 123.30356692928986
# Variância: 57.65251078625565
# Desvio-Padrão: 7.592925048112595

# %% [markdown]
# Esse é o “tamanho típico” da variação em torno de R\$ 122. Na prática, significa que cerca de 68% dos trimestres tiveram valor médio por transação entre
#
#   $$
#     122 - 7{,}4 \approx 114,6 \quad\text{e}\quad 122 + 7{,}4 \approx 129,4.
#   $$
#
# ### Interpretação prática
#
# 1. **Dispersão baixa**
#    Um desvio-padrão de R\$ 7 para um valor em torno de R\$ 122 equivale a um coeficiente de variação de
#
#    $$
#      \frac{7{,}4}{122} \approx 0{,}06\quad(\,6\%\,),
#    $$
#
#    ou seja, as médias trimestrais flutuam em torno de ±6% da média geral.
#
# 2. **Potenciais causas**
#
#    * **Sazonalidade**: se alguns trimestres (ex.: fim de ano) tendem a ter transações maiores, isso eleva o desvio.
#    * **Mudanças estruturais**: a previsibilidade do uso do cartão de crédito, associado a compras parceladas e menor variação em campanhas sazonais, pode contribuir para essa estabilidade.
#
# 3. **Uso da métrica**
#
#    * **Planejamento**: saber que “normalmente” o ticket médio fica entre R\$ 114,6 e R\$ 129,4 ajuda a projetar receitas futuras.
#    * **Detecção de anomalias**: trimestres fora desse intervalo (muito acima ou abaixo) podem merecer investigação.
#
# Em suma, a dispersão é baixa, indicando alta estabilidade no ticket médio do Cartão de Crédito, com valor médio de R$ 122. A variabilidade de cerca de R$ 7,4 entre trimestres sugere que fatores sazonais ou de comportamento do consumidor têm influência limitada sobre esse indicador.

# %% [markdown]
# Cartão de Débito

# %%
x2 = df_cards['valorCartaoDebito'] / df_cards['quantidadeCartaoDebito']
print("Média:", x2.mean())
print("Variância:", x2.var(ddof=0))
print("Desvio-Padrão:", x2.std(ddof=0))
# Out:
# Média: 63.69625376915085
# Variância: 21.3400433033628
# Desvio-Padrão: 4.619528471972307

# %% [markdown]
# Esse é o “tamanho típico” da variação em torno de R\$ 63,90. Na prática, significa que cerca de 68% dos trimestres tiveram valor médio por transação entre
#
# $$
# 63{,}9 - 4{,}6 \approx 59{,}3 \quad\text{e}\quad 63{,}9 + 4{,}6 \approx 68{,}5.
# $$
#
# ### Interpretação prática
#
# 1. **Dispersão baixa**
#    Um desvio-padrão de R\$ 4,6 para um valor em torno de R\$ 63,90 equivale a um coeficiente de variação de
#
#    $$
#    \frac{4{,}6}{63{,}9} \approx 0{,}07\quad(\,7\%\,),
#    $$
#
#    ou seja, as médias trimestrais flutuam em torno de ±7% da média geral.
#
# 2. **Potenciais causas**
#
#    * **Sazonalidade**: embora possa haver variações ao longo do ano, o uso cotidiano do cartão de débito tende a manter o ticket médio mais estável.
#    * **Perfil de uso**: o cartão de débito é frequentemente usado para compras menores e cotidianas, o que naturalmente contribui para uma menor variação entre períodos.
#
# 3. **Uso da métrica**
#
#    * **Planejamento**: saber que “normalmente” o ticket médio fica entre R\$ 59,3 e R\$ 68,5 ajuda a projetar receitas e prever volume de transações com mais precisão.
#    * **Detecção de anomalias**: trimestres com valores fora desse intervalo podem sinalizar mudanças no comportamento do consumidor ou em políticas de uso do cartão.
#
# Em suma, o valor médio por transação com Cartão de Débito é de R\$ 63,90, com uma variabilidade de aproximadamente R\$ 4,6 entre trimestres. A dispersão é baixa, indicando que o comportamento dos usuários é relativamente constante ao longo do tempo nesse meio de pagamento.

# %% [markdown]
# Cartão Pré-Pago

# %%
x3 = df_cards['valorCartaoPrePago'] / df_cards['quantidadeCartaoPrePago']
print("Média:", x3.mean())
print("Variância:", x3.var(ddof=0))
print("Desvio-Padrão:", x3.std(ddof=0))
# Out:
# Média: 32.07839566107721
# Variância: 377.51295420903057
# Desvio-Padrão: 19.429692591727502

# %% [markdown]
# Esse é o “tamanho típico” da variação em torno de R\$ 32,57. Na prática, significa que cerca de 68% dos trimestres tiveram valor médio por transação entre
#
# $$
# 32{,}6 - 19{,}7 \approx 12{,}9 \quad\text{e}\quad 32{,}6 + 19{,}7 \approx 52{,}3.
# $$
#
# ### Interpretação prática
#
# 1. **Dispersão alta**
#    Um desvio-padrão de R\$ 19,7 para um valor em torno de R\$ 32,57 equivale a um coeficiente de variação de
#
#    $$
#    \frac{19{,}7}{32{,}6} \approx 0{,}60\quad(\,60\%\,),
#    $$
#
#    ou seja, as médias trimestrais flutuam em torno de ±60% da média geral — uma variação bastante significativa.
#
# 2. **Potenciais causas**
#
#    * **Uso pontual ou ocasional**: o Cartão Pré-Pago costuma estar associado a públicos específicos (ex.: adolescentes, pessoas sem conta bancária) ou a uso eventual (ex.: vale-presente), o que pode gerar variações bruscas.
#    * **Campanhas promocionais ou eventos sazonais**: distribuições de cartões pré-pagos, bonificações ou programas sociais podem gerar picos de uso em determinados períodos.
#
# 3. **Uso da métrica**
#
#    * **Planejamento**: saber que o ticket médio pode oscilar entre R\$ 12,9 e R\$ 52,3 indica a necessidade de considerar cenários mais amplos em projeções relacionadas ao Cartão Pré-Pago.
#    * **Detecção de anomalias**: devido à alta variabilidade, é necessário analisar com mais contexto qualquer desvio do padrão, pois ele pode ou não representar uma anomalia real.
#
# Em suma, o valor médio por transação com Cartão Pré-Pago é de R\$ 32,57, mas com uma variabilidade bastante alta de cerca de R\$ 19,7 entre trimestres. Isso sugere que o comportamento do usuário nesse meio de pagamento é muito menos previsível, com forte influência de fatores pontuais ou sazonais.

# %% [markdown]
# ## Visualizações Gráficas

# %% [markdown]
# Para complementar o processo de análise de dados vamos gerar alguns gráficos, para isso usaremos a biblioteca 'matplotlib'. Iremos iniciar o estudo comparativo com visões individuais de cada série e depois com todos os cartões agrupados.

# %% [markdown]
# **Histograma**
# Mostra a distribuição de frequências de uma variável numérica dividida em “bins” (intervalos). Cada barra indica quantos valores caem em cada faixa. Use quando quiser entender a forma geral dos dados (simetria, sesgo, picôs múltiplos) e identificar aglomerados ou lacunas.

# %% [markdown]
# Histograma do Cartão de Crédito

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.hist(x1)
plt.title ('Histograma do valor médio por transação de Cartão de Crédito')
plt.xlabel('Valor médio por transação Cartão de Crédito (R$)')
plt.ylabel('Quantidade de transações Cartão de Crédito')
plt.tight_layout()
plt.show()

# %% [markdown]
# Histograma do Cartão de Débito

# %%
plt.figure()
plt.hist(x2)
plt.title ('Histograma do valor médio por transação de Cartão de Débito')
plt.xlabel('Valor médio por transação Cartão de Débito (R$)')
plt.ylabel('Quantidade de transações Cartão de Débito')
plt.tight_layout()
plt.show()

# %% [markdown]
# Histograma do Cartão Pré-Pago

# %%
plt.figure()
plt.hist(x3)
plt.title ('Histograma do valor médio por transação de Cartão Pré-Pago')
plt.xlabel('Valor médio por transação Cartão Pré-Pago (R$)')    
plt.ylabel('Quantidade de transações Cartão Pré-Pago')
plt.tight_layout()
plt.show()

# %% [markdown]
# Histograma comparativo dos Cartões de Crédito, Débito e Pré-Pago

# %%
plt.figure()
plt.hist([x1, x2, x3], bins=20, label=['Crédito', 'Débito', 'Pré-Pago'], alpha=0.7)
plt.title('Histograma do valor médio por transação de Cartões')
plt.xlabel('Valor médio por transação (R$)')
plt.ylabel('Frequência')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# **Distribuição do valor médio por transação por tipo de cartão**
#
# O histograma apresenta a distribuição da frequência dos valores médios por transação nos cartões de Crédito, Débito e Pré-Pago.
#
# **Cartão de Crédito**
# Os valores médios por transação com cartão de crédito concentram-se na faixa entre R$ 110 e R$ 135. A distribuição é relativamente concentrada, com leve dispersão, sugerindo consistência nos hábitos de consumo com esse tipo de cartão. A frequência mais alta está em torno de R$ 125, o que corrobora os achados dos gráficos anteriores de tendência de crescimento e estabilidade em patamar elevado.
#
# **Cartão de Débito**
# A distribuição dos valores médios para o cartão de débito é mais concentrada ainda, entre R$ 58 e R$ 78, com o pico de frequência entre R$ 60 e R$ 65. Isso indica um padrão de uso estável, voltado principalmente para compras de valor intermediário. A ausência de extremos reforça a ideia de que o débito é utilizado em compras cotidianas.
#
# **Cartão Pré-Pago**
# A distribuição dos valores médios por transação com cartões pré-pagos ocorre principalmente entre R$ 15 e R$ 35, com alguns poucos valores maiores (até cerca de R$ 85), que aparecem como exceções. Essa distribuição assimétrica com cauda à direita confirma a forte queda observada na linha do tempo a partir de 2020, além de destacar seu uso predominante para pequenas compras ou transferências de baixo valor.
#
# Em resumo, o histograma reforça as diferenças nos perfis de uso entre os tipos de cartão, com o crédito associado a transações de maior valor, o débito a valores medianos e o pré-pago a pequenas transações com pouca dispersão.

# %% [markdown]
# **Série temporal (line plot)**
# Plota um valor ao longo de um eixo temporal conectado por linhas. Ideal para acompanhar tendências, ciclos sazonais e rupturas em séries de tempo (ex.: evolução do ticket médio dos Cartões trimestre a trimestre). Ajuda a visualizar crescimento, quedas e padrões periódicos.

# %% [markdown]
# Evolução do Valor Médio por Transação do Cartão de Crédito

# %%
plt.figure()
plt.plot(df['datatrimestre'], x1, marker='o', linestyle='-')
plt.title('Evolução do valor médio por transação de Cartão de Crédito')
plt.xlabel('Trimestre')
plt.ylabel('Valor médio por transação (R$)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Evolução do Valor Médio por Transação do Cartão de Débito

# %%
plt.figure()
plt.plot(df['datatrimestre'], x2, marker='o', linestyle='-')
plt.title('Evolução do valor médio por transação de Cartão de Débito')
plt.xlabel('Trimestre')
plt.ylabel('Valor médio por transação (R$)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Evolução do Valor Médio por Transação do Cartão Pré-Pago

# %%
plt.figure()
plt.plot(df['datatrimestre'], x3, marker='o', linestyle='-')
plt.title('Evolução do valor médio por transação de Cartão de Pré-Pago')
plt.xlabel('Trimestre')
plt.ylabel('Valor médio por transação (R$)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Comparação da Evolução do Valor Médio por Transação dos Cartões de Crédito, Débito e Pré-Pago

# %%
plt.figure()
plt.plot(df['datatrimestre'], x1, marker='o', linestyle='-')
plt.plot(df['datatrimestre'], x2, marker='s', linestyle='-')
plt.plot(df['datatrimestre'], x3, marker='^', linestyle='-')
plt.title('Evolução do valor médio por transação dos Cartões de Crédito, Débito e Pré-Pago')
plt.legend(['Crédito', 'Débito', 'Pré-Pago'])
plt.xlabel('Trimestre')
plt.ylabel('Valor médio por transação (R$)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Evolução do valor médio por transação por tipo de cartão**
#
# O gráfico de linha ilustra a evolução temporal do valor médio por transação nos cartões de Crédito, Débito e Pré-Pago, entre 2019 e o início de 2025, com dados organizados por trimestre.
#
# **Cartão de Crédito**
# Há uma tendência clara de crescimento contínuo no valor médio por transação. No início de 2019, o valor girava em torno de R$ 110, com aumento consistente ao longo do tempo, chegando a aproximadamente R$ 135 em 2025. Esse crescimento pode refletir tanto inflação quanto maior uso do crédito para compras de maior valor, especialmente durante e após o período pandêmico.
#
# **Cartão de Débito**
# O valor médio por transação se manteve relativamente estável, variando em torno de R$ 60 durante quase todo o período. Entre 2020 e 2021, há um leve aumento, com pico próximo a R$ 78, possivelmente associado a mudanças no comportamento de consumo durante a pandemia. Depois disso, os valores voltam a se estabilizar em patamar semelhante ao pré-pandemia.
#
# **Cartão Pré-Pago**
# Apresenta uma mudança abrupta no início de 2020, com queda de valores médios de cerca de R$ 85 para aproximadamente R$ 15. Após essa queda, há uma leve recuperação, atingindo valores próximos de R$ 25 nos anos seguintes. Essa transformação pode estar relacionada à maior popularização do uso de cartões pré-pagos para microtransações ou políticas públicas que ampliaram seu uso entre públicos de menor poder aquisitivo.
#
# De maneira geral, o gráfico evidencia padrões distintos de uso entre os três tipos de cartão, refletindo comportamentos financeiros e contextos socioeconômicos diversos ao longo do tempo.

# %% [markdown]
# **Box-plot**
# Representa a mediana, quartis e potenciais outliers de um conjunto de observações. A “caixa” vai do primeiro ao terceiro quartil, com uma linha na mediana, e “bigodes” indicando o alcance dos dados sem outliers. Use para comparar dispersão e simetria entre grupos (por exemplo, diferentes canais de pagamento) e para detectar valores atípicos.

# %% [markdown]
# Box-plot Cartão de Crédito

# %%
plt.figure()
plt.boxplot(x1.dropna())
plt.title('Boxplot do valor médio por transação de Cartão de Crédito')
plt.xlabel('Cartão de Crédito')
plt.ylabel('Valor médio por transação (R$)')
plt.tight_layout()
plt.show()

# %% [markdown]
# Box-Plot Cartão de Débito

# %%
plt.figure()
plt.boxplot(x2.dropna())
plt.title('Boxplot do valor médio por transação de Cartão de Débito')
plt.xlabel('Cartão de Débito')
plt.ylabel('Valor médio por transação (R$)')
plt.tight_layout()
plt.show()

# %% [markdown]
# Box-Plot Cartão Pré-Pago

# %%
plt.figure()
plt.boxplot(x3.dropna())
plt.title('Boxplot do valor médio por transação de Cartão Pré-Pago')
plt.xlabel('Cartão Pré-Pago')
plt.ylabel('Valor médio por transação (R$)')
plt.tight_layout()
plt.show()

# %% [markdown]
# Box-Plot comparativo do Valor Médio por Transação dos Cartões de Crédito, Débito e Pré-Pago

# %%
import matplotlib.pyplot as plt

plt.figure()

# Ajustar as posições para os boxplots
plt.boxplot([x1.dropna(), x2.dropna(), x3.dropna()], positions=[1, 2, 3])

# Melhorar a aparência
plt.xticks([1, 2, 3], ['Cartão de Crédito', 'Cartão de Débito', 'Cartão Pré-Pago'], fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)

# Adicionar título e rótulos
plt.title('Box-plot do valor médio por transação dos Cartões de Crédito, Débito e Pré-Pago', fontsize=14)
plt.xlabel('Cartões', fontsize=12)
plt.ylabel('Valor médio por transação (R$)', fontsize=12)

# Layout ajustado
plt.tight_layout()

# Mostrar o gráfico
plt.show()

# %% [markdown]
# **Boxplot do valor médio por transação por tipo de cartão**
#
# O gráfico apresenta a distribuição dos valores médios por transação, separados por tipo de cartão: Crédito, Débito e Pré-Pago.
#
# **Cartão de Crédito**
# Esse tipo de cartão apresenta os maiores valores médios por transação. A mediana está acima de R$ 125, indicando que a metade das transações ocorre com valores superiores a esse. A variação entre os quartis é pequena, mostrando uma distribuição relativamente estável. Poucos valores extremos foram observados, o que sugere consistência no uso do cartão de crédito para compras de valor mais elevado.
#
# **Cartão de Débito**
# A mediana das transações com débito está por volta de R$ 62. A distribuição é mais compacta e apresenta menor dispersão em comparação com o crédito. Há alguns outliers positivos, indicando que, em casos pontuais, há transações com valores maiores. O débito parece ser utilizado principalmente para compras de valor intermediário e com maior controle.
#
# **Cartão Pré-Pago**
# É o cartão com os menores valores médios por transação. A mediana está em torno de R$ 27, mas há vários outliers acima de R$ 50, inclusive alguns próximos a R$ 85. Isso indica que, embora normalmente utilizado para valores baixos, esse tipo de cartão também é usado eventualmente para valores mais altos, possivelmente quando há concentração de saldo.
#
# Em resumo, observa-se um padrão claro: o cartão de crédito é usado para transações de maior valor, o de débito para valores intermediários e o pré-pago para valores menores, com algumas exceções.

# %%
df.to_csv('transacaoCartao.csv', sep=';', decimal=',')
